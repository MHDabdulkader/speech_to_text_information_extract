# %%
from pydantic_settings import BaseSettings
from dotenv import load_dotenv

class Settings(BaseSettings):
    ASSEMBLYAI_APITOKEN: str
    
    class Config:
        env_file = ".env"
        
        
settings = Settings()

# %%
import assemblyai as aai

aai.settings.api_key = settings.ASSEMBLYAI_APITOKEN

audio_file = "C:/Users/Abdul_Kader/voice recog/basic/harvard_new.wav"
